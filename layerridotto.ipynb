# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import qdatoolkit as qda

layer226 = pd.read_csv('./data/layer_226.csv')

# %%
plt.figure(figsize=(8, 6))
plt.scatter(layer226['x'], layer226['y'], s=1, label='Layer 226')
plt.title('Layer 226')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %%
#calcolo ymin
# Filtra i dati per track_id pari e maggiore o uguale a 85
even_track_ids = layer226[(layer226['track_id'] >= 84)]

# Raggruppa per track_id e ottieni il primo valore di y
first_y_values = even_track_ids.groupby('track_id')['y'].min()
print(first_y_values)
# Trova il valore minimo
max_value = first_y_values.max()

# Stampa i risultati

print(f"Maximum value: {max_value}")
# Out:
# track_id
# 84    -66.660
# 85    -66.539
# 86    -66.648
# 87    -66.541
# 88    -66.650
#         ...
# 168   -66.645
# 169   -66.534
# 170   -66.648
# 171   -66.538
# 172   -66.657
# Name: y, Length: 89, dtype: float64
# Maximum value: -66.522

# %%
#calcolo ymax
# Filtra i dati per track_id pari e maggiore o uguale a 85
last_track_ids = layer226[(layer226['track_id'] <= 84)]

# Raggruppa per track_id e ottieni il primo valore di y
last_y_values = last_track_ids.groupby('track_id')['y'].max()
print(last_y_values)
# Trova il valore minimo
min_value = last_y_values.min()

# Stampa i risultati

print(f"Minimum value: {min_value}")
# Out:
# track_id
# 0    -54.606
# 1    -54.497
# 2    -54.604
# 3    -54.500
# 4    -54.610
#        ...
# 80   -54.610
# 81   -54.492
# 82   -54.619
# 83   -54.489
# 84   -54.614
# Name: y, Length: 85, dtype: float64
# Minimum value: -54.62

# %%
#calcolo xmax
# Filtra i dati per track_id pari e maggiore o uguale a 85
last_track_ids_x = layer226[(layer226['track_id'] >= 84)& (layer226['track_id'] != 172)]

# Raggruppa per track_id e ottieni il primo valore di y
last_x_values = last_track_ids_x.groupby('track_id')['x'].max()
last_x_values = last_x_values[last_x_values > 37]
print(last_x_values)
# Trova il valore minimo
min_value = last_x_values.min()

# Stampa i risultati

print(f"Minimum value: {min_value}")
# Out:
# track_id
# 84     38.069
# 85     38.189
# 86     38.064
# 87     38.180
# 88     38.068
#         ...
# 167    38.177
# 168    38.068
# 169    38.178
# 170    38.068
# 171    38.180
# Name: x, Length: 84, dtype: float64
# Minimum value: 38.06

# %%
#calcolo xmin
# Filtra i dati per track_id pari e maggiore o uguale a 85
first_track_ids_x = layer226[(layer226['track_id'] <= 84)]

# Raggruppa per track_id e ottieni il primo valore di y
first_x_values = first_track_ids_x.groupby('track_id')['x'].min()

print(first_x_values)
# Trova il valore minimo
max_value = first_x_values.max()

# Stampa i risultati

print(f"Maximum value: {max_value}")
# Out:
# track_id
# 0     26.032
# 1     26.134
# 2     26.037
# 3     26.145
# 4     26.034
#        ...
# 80    26.029
# 81    26.144
# 82    26.029
# 83    26.148
# 84    26.020
# Name: x, Length: 85, dtype: float64
# Maximum value: 26.155

# %%
ymin = -66.522+0.1
ymax = -54.62-0.1
xmin = 26.155+0.1
xmax = 38.06 -0.1

range_x = xmax - xmin
range_y = ymax - ymin
print(f"Range of x: {range_x}")
print(f"Range of y: {range_y}")
# Out:
# Range of x: 11.704999999999998
# Range of y: 11.702000000000012

# %%
filtered_dataset_226 = layer226[(layer226['x'] >= xmin) & (layer226['x'] <= xmax) & 
                            (layer226['y'] >= ymin) & (layer226['y'] <= ymax)]
print(filtered_dataset_226)

# Salva il dataset filtrato in un file CSV
filtered_dataset_226.to_csv('./Reducedlayers/layer_226_reduced.csv', index=False)
# Out:
#                   t       x       y     z  layer_id  sensor0  sensor1    temp  \
# 109     156772420.0  26.261 -54.780  9.04       226    875.0    873.0  1590.2
# 110     156772430.0  26.264 -54.774  9.04       226    881.0    884.0  1584.0
# 111     156772440.0  26.269 -54.770  9.04       226    887.0    883.0  1592.7
# 112     156772450.0  26.279 -54.763  9.04       226    883.0    881.0  1590.2
# 113     156772460.0  26.283 -54.759  9.04       226    888.0    889.0  1586.5
# ...             ...     ...     ...   ...       ...      ...      ...     ...
# 180915  158918280.0  37.936 -66.388  9.04       226    927.0    966.0  1543.5
# 180916  158918290.0  37.940 -66.386  9.04       226    937.0    974.0  1546.1
# 180917  158918300.0  37.945 -66.380  9.04       226    928.0    971.0  1539.2
# 180918  158918310.0  37.950 -66.374  9.04       226    931.0    977.0  1536.2
# 180919  158918320.0  37.957 -66.366  9.04       226    930.0    974.0  1538.3
#
# ...

# %%
plt.figure(figsize=(8, 6))
plt.scatter(filtered_dataset_226['x'], filtered_dataset_226['y'], s=1)
plt.title('Layer 226')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
layer224 = pd.read_csv('./data/layer_224.csv')
plt.figure(figsize=(8, 6))
plt.scatter(layer224['x'], layer224['y'], s=1, label='Layer 224')
plt.title('Layer 224')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %%
filtered_dataset_224 = layer224[(layer224['x'] >= xmin) & (layer224['x'] <= xmax) & 
                                (layer224['y'] >= ymin) & (layer224['y'] <= ymax)]
print(filtered_dataset_224)
# Salva il dataset filtrato in un file CSV
filtered_dataset_224.to_csv('./Reducedlayers/layer_224_reduced.csv', index=False)
# Out:
#                   t       x       y     z  layer_id  sensor0  sensor1    temp  \
# 860     127889750.0  37.921 -54.720  8.96       224    855.0    874.0  1563.8
# 861     127889760.0  37.925 -54.728  8.96       224    859.0    876.0  1566.4
# 862     127889770.0  37.925 -54.733  8.96       224    859.0    873.0  1570.1
# 863     127889780.0  37.921 -54.745  8.96       224    858.0    859.0  1586.4
# 864     127889790.0  37.924 -54.752  8.96       224    856.0    879.0  1559.0
# ...             ...     ...     ...   ...       ...      ...      ...     ...
# 180346  129921660.0  26.284 -66.385  8.96       224    871.0    910.0  1540.8
# 180347  129921670.0  26.285 -66.397  8.96       224    886.0    902.0  1568.2
# 180348  129921680.0  26.284 -66.404  8.96       224    882.0    908.0  1556.3
# 180349  129921690.0  26.281 -66.409  8.96       224    888.0    907.0  1564.7
# 180350  129921700.0  26.282 -66.418  8.96       224    890.0    916.0  1556.5
#
# ...

# %%
plt.figure(figsize=(8, 6))
plt.scatter(filtered_dataset_224['x'], filtered_dataset_224['y'], s=1)
plt.title('Layer 224')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
layer225 = pd.read_csv('./data/layer_225.csv')
plt.figure(figsize=(8, 6))
plt.scatter(layer225['x'], layer225['y'], s=1, label='Layer 225')
plt.title('Layer 225')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %%
filtered_dataset_225 = layer225[(layer225['x'] >= xmin) & (layer225['x'] <= xmax) & 
                            (layer225['y'] >= ymin) & (layer225['y'] <= ymax)]
print(filtered_dataset_225)# Salva il dataset filtrato in un file CSV
filtered_dataset_225.to_csv('./Reducedlayers/layer_225_reduced.csv', index=False)
# Out:
#                   t       x       y    z  layer_id  sensor0  sensor1    temp  \
# 167     151059460.0  37.954 -54.835  9.0       225    890.0    866.0  1618.5
# 168     151059470.0  37.947 -54.829  9.0       225    897.0    873.0  1618.2
# 169     151059480.0  37.936 -54.821  9.0       225    886.0    878.0  1597.8
# 170     151059490.0  37.931 -54.819  9.0       225    890.0    878.0  1602.8
# 171     151059500.0  37.926 -54.816  9.0       225    883.0    882.0  1589.0
# ...             ...     ...     ...  ...       ...      ...      ...     ...
# 181247  153155380.0  26.289 -66.355  9.0       225    929.0    964.0  1547.9
# 181248  153155390.0  26.279 -66.351  9.0       225    933.0    956.0  1561.3
# 181249  153155400.0  26.269 -66.348  9.0       225    937.0    953.0  1569.2
# 181250  153155410.0  26.264 -66.344  9.0       225    931.0    951.0  1564.6
# 181251  153155420.0  26.256 -66.341  9.0       225    929.0    946.0  1567.9
#
# ...

# %%
plt.figure(figsize=(8, 6))
plt.scatter(filtered_dataset_225['x'], filtered_dataset_225['y'], s=1)
plt.title('Layer 225')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
layer227 = pd.read_csv('./data/layer_227.csv')
plt.figure(figsize=(8, 6))
plt.scatter(layer227['x'], layer227['y'], s=1, label='Layer 227')
plt.title('Layer 227')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %%
filtered_dataset_227 = layer227[(layer227['x'] >= xmin) & (layer227['x'] <= xmax) & 
                            (layer227['y'] >= ymin) & (layer227['y'] <= ymax)]
print(filtered_dataset_227)
# Salva il dataset filtrato in un file CSV
filtered_dataset_227.to_csv('./Reducedlayers/layer_227_reduced.csv', index=False)
# Out:
#                  t       x       y     z  layer_id  sensor0  sensor1    temp  \
# 179     90552970.0  26.259 -66.232  9.08       227    890.0    903.0  1571.9
# 180     90552980.0  26.264 -66.240  9.08       227    885.0    904.0  1564.6
# 181     90552990.0  26.266 -66.242  9.08       227    886.0    895.0  1576.6
# 182     90553000.0  26.268 -66.251  9.08       227    903.0    908.0  1581.6
# 183     90553010.0  26.270 -66.254  9.08       227    883.0    899.0  1568.1
# ...            ...     ...     ...   ...       ...      ...      ...     ...
# 181052  92641610.0  37.951 -54.985  9.08       227    925.0    985.0  1521.2
# 181053  92641620.0  37.952 -54.991  9.08       227    917.0    985.0  1512.5
# 181054  92641630.0  37.959 -54.996  9.08       227    917.0    992.0  1505.4
# 181176  92644140.0  37.956 -54.728  9.08       227    969.0   1012.0  1541.2
# 181177  92644150.0  37.952 -54.722  9.08       227    942.0   1011.0  1513.3
#
# ...

# %%
plt.figure(figsize=(8, 6))
plt.scatter(filtered_dataset_227['x'], filtered_dataset_227['y'], s=1)
plt.title('Layer 227')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
layer228 = pd.read_csv('./data/layer_228.csv')
plt.figure(figsize=(8, 6))
plt.scatter(layer228['x'], layer228['y'], s=1, label='Layer 228')
plt.title('Layer 228')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %%
filtered_dataset_228 = layer228[(layer228['x'] >= xmin) & (layer228['x'] <= xmax) & 
                            (layer228['y'] >= ymin) & (layer228['y'] <= ymax)]
print(filtered_dataset_228)
# Salva il dataset filtrato in un file CSV
filtered_dataset_228.to_csv('./Reducedlayers/layer_228_reduced.csv', index=False)
# Out:
#                  t       x       y     z  layer_id  sensor0  sensor1    temp  \
# 2832    96061830.0  27.757 -66.421  9.12       228    897.0    894.0  1591.4
# 2843    96061940.0  27.672 -66.421  9.12       228    897.0    898.0  1586.5
# 2844    96061950.0  27.664 -66.420  9.12       228    900.0    897.0  1591.4
# 2847    96061980.0  27.638 -66.421  9.12       228    886.0    884.0  1590.2
# 2849    96062000.0  27.618 -66.421  9.12       228    909.0    904.0  1593.8
# ...            ...     ...     ...   ...       ...      ...      ...     ...
# 178866  98062090.0  35.728 -54.722  9.12       228    951.0    992.0  1542.4
# 178867  98062100.0  35.722 -54.722  9.12       228    959.0    991.0  1552.3
# 178868  98062110.0  35.718 -54.723  9.12       228    949.0    996.0  1536.1
# 178869  98062120.0  35.710 -54.721  9.12       228    963.0    999.0  1548.2
# 178871  98062140.0  35.691 -54.721  9.12       228    946.0   1004.0  1524.6
#
# ...

# %%
plt.figure(figsize=(8, 6))
plt.scatter(filtered_dataset_228['x'], filtered_dataset_228['y'], s=1)
plt.title('Layer 228')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Leggi i dataset ridotti
layers = [
    pd.read_csv('./Reducedlayers/layer_224_reduced.csv'),
    pd.read_csv('./Reducedlayers/layer_225_reduced.csv'),
    pd.read_csv('./Reducedlayers/layer_228_reduced.csv')
]

# Unisci i dataset sui valori di x e y
merged = layers[0][['x', 'y']]
for layer in layers[1:]:
    merged = pd.merge(merged, layer[['x', 'y']], on=['x', 'y'], how='inner')

# Conta i punti comuni
common_points_count = len(merged)
print(f"Number of points with the same x and y in all 5 layers: {common_points_count}")
# Out:
# Number of points with the same x and y in all 5 layers: 0
